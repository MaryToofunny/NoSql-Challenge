# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
# confirm that our new database was created
db=mongo['uk_food']
print(mongo.list_database_names())
# Out:
# ['admin', 'autosaurus', 'classDB', 'config', 'local', 'petsitly_marketing', 'uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments=db['establishments']

# %%
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63ce95eec8002f45dd6d091c'),
#  'geocode': {'latitude': 51.083812, 'longitude': 1.195625},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20

query = { 'scores.Hygiene':{'$eq' : 20}}
fields = {'BusinessName':1,'BusinessType': 1,'LocalAuthorityName':1,'scores.Hygiene': 1}

results = establishments.find(query, fields)
results

# %%
# Use count_documents to display the number of documents in the result

Hygine_Count = establishments.count_documents({'scores.Hygiene': {'$eq':20}})
Hygine_Count
# Out:
# 41

# %%
# Display the first document in the results using pprint
pprint(results[0])
# Out:
# {'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'LocalAuthorityName': 'Eastbourne',
#  '_id': ObjectId('63ce95eec8002f45dd6d2451'),
#  'scores': {'Hygiene': 20}}

# %%
# Convert the result to a Pandas DataFrame
result_df = pd.DataFrame(list(results))

# %%
# Display the number of rows in the DataFrame
print("Rows in DataFrame: ", len(result_df))

# Display the first 10 rows of the DataFrame
result_df.head(10)
# Out:
# Rows in DataFrame:  41
#                         _id               BusinessName  \
# 0  63ce95eec8002f45dd6d2451        The Chase Rest Home
# 1  63ce95eec8002f45dd6d27ce                 Brenalwood
# 2  63ce95eec8002f45dd6d2adc              Melrose Hotel
# 3  63ce95eec8002f45dd6d2cc8              Seaford Pizza
# 4  63ce95eec8002f45dd6d2cd9              Golden Palace
# 5  63ce95efc8002f45dd6d3678           Ashby's Butchers
# 6  63ce95efc8002f45dd6d3899  South Sea Express Cuisine
# 7  63ce95efc8002f45dd6d4dc0              Golden Palace
# 8  63ce95efc8002f45dd6d520b             The Tulip Tree
# 9  63ce95efc8002f45dd6d5a13                      F & S
#
#                         BusinessType LocalAuthorityName           scores
# 0                    Caring Premises         Eastbourne  {'Hygiene': 20}
# 1                    Caring Premises           Tendring  {'Hygiene': 20}
# 2  Hotel/bed & breakfast/guest house           Tendring  {'Hygiene': 20}
# 3             Takeaway/sandwich shop              Lewes  {'Hygiene': 20}
# 4            Restaurant/Cafe/Canteen              Lewes  {'Hygiene': 20}
# 5                  Retailers - other    Southend-On-Sea  {'Hygiene': 20}
# 6            Restaurant/Cafe/Canteen    Southend-On-Sea  {'Hygiene': 20}
# 7             Takeaway/sandwich shop           Rochford  {'Hygiene': 20}
# 8            Restaurant/Cafe/Canteen          Sevenoaks  {'Hygiene': 20}
# 9                  Retailers - other           Basildon  {'Hygiene': 20}

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {'LocalAuthorityName':{'$regex':'London'},'RatingValue' :{'$gte':"4"}}
fields = {'BusinessName':1,'BusinessType': 1,'LocalAuthorityName':1,'RatingValue': 1}
                                                           
results=establishments.find(query, fields)

# %%
# Use count_documents to display the number of documents in the result
LondonRatingValue_Count = establishments.count_documents(query)
LondonRatingValue_Count
# Out:
# 34

# %%
# Display the first document in the results using pprint
print(results[0])
# Out:
# {'_id': ObjectId('63ce95efc8002f45dd6d3e6d'), 'BusinessName': "Charlie's", 'BusinessType': 'Other catering premises', 'RatingValue': '4', 'LocalAuthorityName': 'City of London Corporation'}

# %%
# Convert the result to a Pandas DataFrame
result_df=pd.DataFrame(list(results))

# Display the number of rows in the DataFrame
print("Rows in DataFrame: ", len(result_df))

# Display the first 10 rows of the DataFrame
result_df.head(10)
# Out:
# Rows in DataFrame:  34
#                         _id                          BusinessName  \
# 0  63ce95efc8002f45dd6d3e6d                             Charlie's
# 1  63ce95efc8002f45dd6d4192               Mv City Cruises Erasmus
# 2  63ce95efc8002f45dd6d4cdf             Benfleet Motor Yacht Club
# 3  63ce95efc8002f45dd6d5ade              Tilbury Seafarers Centre
# 4  63ce95efc8002f45dd6d5ae0  Coombs Catering t/a The Lock and Key
# 5  63ce95efc8002f45dd6d61e7                            Mv Valulla
# 6  63ce95efc8002f45dd6d82f4                         Tereza Joanne
# 7  63ce95efc8002f45dd6d82f5                             Froottree
# 8  63ce95efc8002f45dd6d86bd                      Brick Lane Brews
# 9  63ce95efc8002f45dd6d86d6                      City Bar & Grill
#
#               BusinessType         RatingValue          LocalAuthorityName
# 0  Other catering premises                   4  City of London Corporation
# 1  Other catering premises                   5  City of London Corporation
# 2  Other catering premises                   4  City of London Corporation
# 3  Restaurant/Cafe/Canteen                   5  City of London Corporation
# 4  Restaurant/Cafe/Canteen                   5  City of London Corporation
# 5  Other catering premises                   5  City of London Corporation
# 6  Other catering premises                   5  City of London Corporation
# 7  Other catering premises  AwaitingInspection  City of London Corporation
# 8  Restaurant/Cafe/Canteen                   4  City of London Corporation
# 9  Restaurant/Cafe/Canteen                   5  City of London Corporation

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of '5', sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

#finding long and lat for Penang Flavours
results=db.establishments.find_one({'BusinessName': 'Penang Flavours'})
pprint(results)
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63ce9725df8f44a7d16fe66a'),
#  'geocode': {'latitude': 51.490142, 'longitude': 0.08384},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %%
degree_search = 0.01
latitude = results["geocode"]["latitude"]
longitude = results['geocode']["longitude"]

print(latitude)
print(longitude)
# Out:
# 51.490142
# 0.08384

# %%
query = {'RatingValue':'5','geocode.latitude':{'$lte' :latitude+degree_search,'$gte':latitude-degree_search},
         'geocode.longitude':{'$lte' :longitude+degree_search,'$gte':longitude-degree_search}}       
fields = {'BusinessName':1,'BusinessType': 1,'LocalAuthorityName':1,'RatingValue': 1,'scores.Hygiene':1,'geocode.latitude':1,'geocode.longitude':1}
sort=[('scores.Hygiene',1)]
                                                           
results=establishments.find(query, fields).sort(sort)


# Print the results
         
for result in results:
    pprint(result)
# Out:
# {'BusinessName': 'Iceland',
#  'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7c83'),
#  'geocode': {'latitude': 51.4871482849121, 'longitude': 0.0924199968576431},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Howe and Co Fish and Chips - Van 17',
#  'BusinessType': 'Mobile caterer',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7c93'),
#  'geocode': {'latitude': 51.4875335693359, 'longitude': 0.0925370007753372},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Volunteer',
#  'BusinessType': 'Pub/bar/nightclub',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7cb0'),
#  'geocode': {'latitude': 51.4873437, 'longitude': 0.09208},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Plumstead Manor Nursery',
#  'BusinessType': 'Caring Premises',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7cc8'),
#  'geocode': {'latitude': 51.481517791748, 'longitude': 0.0859939977526665},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Atlantic Fish Bar',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7ccb'),
#  'geocode': {'latitude': 51.4867296, 'longitude': 0.0912164},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Lumbini Grocery Ltd T/A Al-Iman',
#  'BusinessType': 'Retailers - other',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7ccd'),
#  'geocode': {'latitude': 51.4871632, 'longitude': 0.0916256},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Tesco',
#  'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7ce9'),
#  'geocode': {'latitude': 51.4871406555176, 'longitude': 0.0912820026278496},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Greggs',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7ced'),
#  'geocode': {'latitude': 51.4871406555176, 'longitude': 0.0912820026278496},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Dosa & Sambal Express',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7d13'),
#  'geocode': {'latitude': 51.4877576, 'longitude': 0.091566},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Abbi Wines',
#  'BusinessType': 'Retailers - other',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7d15'),
#  'geocode': {'latitude': 51.4871401, 'longitude': 0.0908895},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Dilkush Tandoori',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7d4c'),
#  'geocode': {'latitude': 51.4878941, 'longitude': 0.0909672},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': "Dadoo's Foodstore",
#  'BusinessType': 'Retailers - other',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7d63'),
#  'geocode': {'latitude': 51.4876894, 'longitude': 0.0905233},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'High Street News & Wine',
#  'BusinessType': 'Retailers - other',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7d6e'),
#  'geocode': {'latitude': 51.4876718, 'longitude': 0.0903232},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'The Old Mill',
#  'BusinessType': 'Pub/bar/nightclub',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7d7f'),
#  'geocode': {'latitude': 51.4817109, 'longitude': 0.0840959},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'The Belfry',
#  'BusinessType': 'Pub/bar/nightclub',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7d92'),
#  'geocode': {'latitude': 51.487928, 'longitude': 0.0900757},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Chick Chicken',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7dad'),
#  'geocode': {'latitude': 51.4880687, 'longitude': 0.0897508},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Conway Primary School',
#  'BusinessType': 'School/college/university',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7db3'),
#  'geocode': {'latitude': 51.487865447998, 'longitude': 0.0894860029220581},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Best Halal Meat Limited',
#  'BusinessType': 'Retailers - other',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7dc5'),
#  'geocode': {'latitude': 51.4881611, 'longitude': 0.089611},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Boba & Co UK',
#  'BusinessType': 'Other catering premises',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7ddf'),
#  'geocode': {'latitude': 51.4881627, 'longitude': 0.0895246},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Poundland',
#  'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7df5'),
#  'geocode': {'latitude': 51.4884195010951, 'longitude': 0.0893575026992294},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'SD News & Mini Market',
#  'BusinessType': 'Retailers - other',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7e08'),
#  'geocode': {'latitude': 51.4827461242676, 'longitude': 0.0831020027399063},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'KFC',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7e14'),
#  'geocode': {'latitude': 51.4884997, 'longitude': 0.0887766},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Co-op Food',
#  'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7e19'),
#  'geocode': {'latitude': 51.4806876203642, 'longitude': 0.0808583091748281},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Ambala & Karahi Ltd',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7e29'),
#  'geocode': {'latitude': 51.4885934, 'longitude': 0.0885648},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Los carnales mexicanos',
#  'BusinessType': 'Mobile caterer',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7e63'),
#  'geocode': {'latitude': 51.4810979, 'longitude': 0.0802144},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'East Plumstead Pre School',
#  'BusinessType': 'Caring Premises',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7e64'),
#  'geocode': {'latitude': 51.4845542907715, 'longitude': 0.0836590006947517},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Plumstead Common Petrol Station',
#  'BusinessType': 'Retailers - other',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7e75'),
#  'geocode': {'latitude': 51.4806732, 'longitude': 0.0793165},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'My Home (Plumstead)',
#  'BusinessType': 'Other catering premises',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7e86'),
#  'geocode': {'latitude': 51.4860247, 'longitude': 0.0843422},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'St Patricks Social Club',
#  'BusinessType': 'Pub/bar/nightclub',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7e8e'),
#  'geocode': {'latitude': 51.487438, 'longitude': 0.0852709},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Deescon Freight',
#  'BusinessType': 'Retailers - other',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7e93'),
#  'geocode': {'latitude': 51.4890121, 'longitude': 0.0868772},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Star INN',
#  'BusinessType': 'Pub/bar/nightclub',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7e9a'),
#  'geocode': {'latitude': 51.4808120727539, 'longitude': 0.0785060003399849},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Bear Hugs Day Nursery',
#  'BusinessType': 'Caring Premises',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7ea4'),
#  'geocode': {'latitude': 51.4838756, 'longitude': 0.0812914},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Roundhouse Food and Wine',
#  'BusinessType': 'Retailers - other',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7ea6'),
#  'geocode': {'latitude': 51.4847465, 'longitude': 0.0820677},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'U&A Foods Ltd',
#  'BusinessType': 'Retailers - other',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7eb0'),
#  'geocode': {'latitude': 51.4892023, 'longitude': 0.086187},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': "St. Patrick's School",
#  'BusinessType': 'School/college/university',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7eb6'),
#  'geocode': {'latitude': 51.4884185791016, 'longitude': 0.0853480026125908},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Kings Cafe',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7eba'),
#  'geocode': {'latitude': 51.4892216, 'longitude': 0.0861158},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Peace Manor Residential Care',
#  'BusinessType': 'Caring Premises',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7ebd'),
#  'geocode': {'latitude': 51.484673, 'longitude': 0.0814574},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Danfe Restaurant',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7ee2'),
#  'geocode': {'latitude': 51.4893348, 'longitude': 0.0853618},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'The Eggfree Cake Box (Plumstead)',
#  'BusinessType': 'Retailers - other',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7ef2'),
#  'geocode': {'latitude': 51.4896464707035, 'longitude': 0.0857344851907352},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': "McDonald's",
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7f20'),
#  'geocode': {'latitude': 51.4908567, 'longitude': 0.0853967},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Jhas Catering Services',
#  'BusinessType': 'Other catering premises',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7f27'),
#  'geocode': {'latitude': 51.4900815, 'longitude': 0.0842824},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Wilson & Bay Coffee Club',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7f2a'),
#  'geocode': {'latitude': 51.4897501, 'longitude': 0.0839053},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'D J Off Licence',
#  'BusinessType': 'Retailers - other',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7f31'),
#  'geocode': {'latitude': 51.4862246, 'longitude': 0.0801741},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Suya Academy Ltd',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7f35'),
#  'geocode': {'latitude': 51.4901495, 'longitude': 0.0839974},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Om Stop & Go',
#  'BusinessType': 'Retailers - other',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7f3a'),
#  'geocode': {'latitude': 51.4835927, 'longitude': 0.0771598},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Waterside Primary School',
#  'BusinessType': 'School/college/university',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7f3d'),
#  'geocode': {'latitude': 51.4873504638672, 'longitude': 0.0810069963335991},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'The Rose Inn',
#  'BusinessType': 'Pub/bar/nightclub',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7f51'),
#  'geocode': {'latitude': 51.486075, 'longitude': 0.0789717},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Greenwich Islamic Centre',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7f5f'),
#  'geocode': {'latitude': 51.4903258, 'longitude': 0.0824813},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': "St Margaret's C of E Primary School",
#  'BusinessType': 'School/college/university',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7f62'),
#  'geocode': {'latitude': 51.4824142456055, 'longitude': 0.074412003159523},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Bal Krishna Nursery',
#  'BusinessType': 'Caring Premises',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7f63'),
#  'geocode': {'latitude': 51.4824256896973, 'longitude': 0.0743729993700981},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Fresh Chances',
#  'BusinessType': 'Other catering premises',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7f74'),
#  'geocode': {'latitude': 51.4863955, 'longitude': 0.0776292},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Quaggy at Margaret Bondfield',
#  'BusinessType': 'Caring Premises',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7f75'),
#  'geocode': {'latitude': 51.4863967895508, 'longitude': 0.0776320025324821},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Tesco',
#  'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7f76'),
#  'geocode': {'latitude': 51.4989512, 'longitude': 0.0902181},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': "Domino's Pizza",
#  'BusinessType': 'Takeaway/sandwich shop',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7f84'),
#  'geocode': {'latitude': 51.4987492, 'longitude': 0.0895991},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Ashgreen House',
#  'BusinessType': 'Caring Premises',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7fcf'),
#  'geocode': {'latitude': 51.4871520996094, 'longitude': 0.075984999537468},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Heronsgate Primary School Thamesmead Campus',
#  'BusinessType': 'School/college/university',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7fd8'),
#  'geocode': {'latitude': 51.4940567016602, 'longitude': 0.0827509984374046},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Breakfast Club',
#  'BusinessType': 'School/college/university',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7fe6'),
#  'geocode': {'latitude': 51.4950485229492, 'longitude': 0.0835620015859604},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'BR6',
#  'BusinessType': 'School/college/university',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7feb'),
#  'geocode': {'latitude': 51.4903331, 'longitude': 0.0787421},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Catering & Hospitality Education Dep',
#  'BusinessType': 'School/college/university',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7fec'),
#  'geocode': {'latitude': 51.4903331, 'longitude': 0.0787421},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'The Real Deal',
#  'BusinessType': 'Other catering premises',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d8040'),
#  'geocode': {'latitude': 51.4978398, 'longitude': 0.0844204},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Borna',
#  'BusinessType': 'Manufacturers/packers',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d8063'),
#  'geocode': {'latitude': 51.4918377, 'longitude': 0.0774802},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Blossom Place Olive Services',
#  'BusinessType': 'Caring Premises',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d807a'),
#  'geocode': {'latitude': 51.4942476, 'longitude': 0.0795886},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Menagerie Cafe',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d80a4'),
#  'geocode': {'latitude': 51.4914321899414, 'longitude': 0.075545996427536},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Innova Nutraceutics Ltd',
#  'BusinessType': 'Retailers - other',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d80b0'),
#  'geocode': {'latitude': 51.4935863, 'longitude': 0.0770593},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Brighter Futures Project',
#  'BusinessType': 'School/college/university',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d80f1'),
#  'geocode': {'latitude': 51.4922421, 'longitude': 0.0739989},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Foodelo',
#  'BusinessType': 'Retailers - other',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d8110'),
#  'geocode': {'latitude': 51.4923133850098, 'longitude': 0.0744580030441284},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'TIWA N TIWA African Restaurant Ltd',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7c5c'),
#  'geocode': {'latitude': 51.4870351, 'longitude': 0.0927429},
#  'scores': {'Hygiene': 5}}
# {'BusinessName': 'Fineway Cash & Carry',
#  'BusinessType': 'Retailers - other',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7d39'),
#  'geocode': {'latitude': 51.4876089, 'longitude': 0.0909382},
#  'scores': {'Hygiene': 5}}
# {'BusinessName': 'Lucky Food & Wine',
#  'BusinessType': 'Retailers - other',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7d4a'),
#  'geocode': {'latitude': 51.4878934, 'longitude': 0.0910104},
#  'scores': {'Hygiene': 5}}
# {'BusinessName': 'Premier Express',
#  'BusinessType': 'Retailers - other',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7d6a'),
#  'geocode': {'latitude': 51.4877234, 'longitude': 0.0904552},
#  'scores': {'Hygiene': 5}}
# {'BusinessName': 'Everest Stores Ltd',
#  'BusinessType': 'Retailers - other',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7d80'),
#  'geocode': {'latitude': 51.4876718, 'longitude': 0.0903232},
#  'scores': {'Hygiene': 5}}
# {'BusinessName': 'The Plumstead Pantry',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7da7'),
#  'geocode': {'latitude': 51.4817727, 'longitude': 0.083745},
#  'scores': {'Hygiene': 5}}
# {'BusinessName': 'Spice Island',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7dfa'),
#  'geocode': {'latitude': 51.4804420471191, 'longitude': 0.0812250003218651},
#  'scores': {'Hygiene': 5}}
# {'BusinessName': 'Apna Grill',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7e77'),
#  'geocode': {'latitude': 51.4870876, 'longitude': 0.0857591},
#  'scores': {'Hygiene': 5}}
# {'BusinessName': "Flames Kebab Ltd trading as Morley's",
#  'BusinessType': 'Takeaway/sandwich shop',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7e78'),
#  'geocode': {'latitude': 51.4810714, 'longitude': 0.0796803},
#  'scores': {'Hygiene': 5}}
# {'BusinessName': 'Conway Road Supermarket',
#  'BusinessType': 'Retailers - other',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7e7c'),
#  'geocode': {'latitude': 51.4873374, 'longitude': 0.0858713},
#  'scores': {'Hygiene': 5}}
# {'BusinessName': 'The Plum Tree Beer Shop',
#  'BusinessType': 'Pub/bar/nightclub',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7e8d'),
#  'geocode': {'latitude': 51.4808287, 'longitude': 0.078661},
#  'scores': {'Hygiene': 5}}
# {'BusinessName': "Chef's House",
#  'BusinessType': 'Takeaway/sandwich shop',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7e9b'),
#  'geocode': {'latitude': 51.4808120727539, 'longitude': 0.0785060003399849},
#  'scores': {'Hygiene': 5}}
# {'BusinessName': 'Cafe Deluxe',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7ec5'),
#  'geocode': {'latitude': 51.4891019, 'longitude': 0.0857646},
#  'scores': {'Hygiene': 5}}
# {'BusinessName': "Malai Restaurant/Ghandi's/Sweet Sensationz/JusBoba",
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7ecd'),
#  'geocode': {'latitude': 51.489315, 'longitude': 0.0859184},
#  'scores': {'Hygiene': 5}}
# {'BusinessName': 'Mr Uncles Kebab',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7ed7'),
#  'geocode': {'latitude': 51.4893255, 'longitude': 0.0858325},
#  'scores': {'Hygiene': 5}}
# {'BusinessName': 'Plumstead Radical Club',
#  'BusinessType': 'Pub/bar/nightclub',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7ef0'),
#  'geocode': {'latitude': 51.4893112182617, 'longitude': 0.084697000682354},
#  'scores': {'Hygiene': 5}}
# {'BusinessName': 'Nisa Local',
#  'BusinessType': 'Retailers - other',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7f05'),
#  'geocode': {'latitude': 51.4861922, 'longitude': 0.0809311},
#  'scores': {'Hygiene': 5}}
# {'BusinessName': 'Brew Station',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7f0c'),
#  'geocode': {'latitude': 51.4899426, 'longitude': 0.0846755},
#  'scores': {'Hygiene': 5}}
# {'BusinessName': 'GMT Kitchen and Cafe',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d7fea'),
#  'geocode': {'latitude': 51.4903331, 'longitude': 0.0787421},
#  'scores': {'Hygiene': 5}}
# {'BusinessName': 'Heronsgate Primary School Royal Arsenal Campus',
#  'BusinessType': 'School/college/university',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d80a0'),
#  'geocode': {'latitude': 51.4898490905762, 'longitude': 0.074074998497963},
#  'scores': {'Hygiene': 5}}
# {'BusinessName': 'PLOT Roasting',
#  'BusinessType': 'Other catering premises',
#  'LocalAuthorityName': 'Greenwich',
#  'RatingValue': '5',
#  '_id': ObjectId('63ce95efc8002f45dd6d80af'),
#  'geocode': {'latitude': 51.4935863, 'longitude': 0.0770593},
#  'scores': {'Hygiene': 5}}

# %%
# Convert result to Pandas DataFrame
result_df=pd.DataFrame(list(establishments.find(query, fields).sort(sort)))

# Display the number of rows in the DataFrame
print("Rows in DataFrame: ", len(result_df))

# Display the first 10 rows of the DataFrame
result_df.head(10)
# Out:
# Rows in DataFrame:  87
#                         _id                         BusinessName  \
# 0  63ce95efc8002f45dd6d7c83                              Iceland
# 1  63ce95efc8002f45dd6d7c93  Howe and Co Fish and Chips - Van 17
# 2  63ce95efc8002f45dd6d7cb0                            Volunteer
# 3  63ce95efc8002f45dd6d7cc8              Plumstead Manor Nursery
# 4  63ce95efc8002f45dd6d7ccb                    Atlantic Fish Bar
# 5  63ce95efc8002f45dd6d7ccd      Lumbini Grocery Ltd T/A Al-Iman
# 6  63ce95efc8002f45dd6d7ce9                                Tesco
# 7  63ce95efc8002f45dd6d7ced                               Greggs
# 8  63ce95efc8002f45dd6d7d13                Dosa & Sambal Express
# 9  63ce95efc8002f45dd6d7d15                           Abbi Wines
#
#                             BusinessType RatingValue LocalAuthorityName  \
# 0  Retailers - supermarkets/hypermarkets           5          Greenwich
# 1                         Mobile caterer           5          Greenwich
# 2                      Pub/bar/nightclub           5          Greenwich
# 3                        Caring Premises           5          Greenwich
# 4                 Takeaway/sandwich shop           5          Greenwich
# 5                      Retailers - other           5          Greenwich
# 6  Retailers - supermarkets/hypermarkets           5          Greenwich
# 7                 Takeaway/sandwich shop           5          Greenwich
# 8                Restaurant/Cafe/Canteen           5          Greenwich
# 9                      Retailers - other           5          Greenwich
#
#            scores                                            geocode
# 0  {'Hygiene': 0}  {'longitude': 0.0924199968576431, 'latitude': ...
# 1  {'Hygiene': 0}  {'longitude': 0.0925370007753372, 'latitude': ...
# 2  {'Hygiene': 0}     {'longitude': 0.09208, 'latitude': 51.4873437}
# 3  {'Hygiene': 0}  {'longitude': 0.0859939977526665, 'latitude': ...
# 4  {'Hygiene': 0}   {'longitude': 0.0912164, 'latitude': 51.4867296}
# 5  {'Hygiene': 0}   {'longitude': 0.0916256, 'latitude': 51.4871632}
# 6  {'Hygiene': 0}  {'longitude': 0.0912820026278496, 'latitude': ...
# 7  {'Hygiene': 0}  {'longitude': 0.0912820026278496, 'latitude': ...
# 8  {'Hygiene': 0}    {'longitude': 0.091566, 'latitude': 51.4877576}
# 9  {'Hygiene': 0}   {'longitude': 0.0908895, 'latitude': 51.4871401}

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0

match_query = {'$match': {'scores.Hygiene': {'$eq':0}}}

# 2. Groups the matches by Local Authority


group_query = {'$group': {'_id': "$LocalAuthorityName", 
                          'LocalAuthority_count': { '$sum': 1 },
                          }}
# 3. Sorts the matches from highest to lowest

sort_values = {'$sort': { 'LocalAuthority_count': -1 }}


pipeline = [match_query, group_query, sort_values]


# Print the number of documents in the result
results = list(establishments.aggregate(pipeline))

print("Number of documents in results: ", len(results))
# Print the first 10 results
pprint(results[0:10])
# Out:
# Number of documents in results:  55
# [{'LocalAuthority_count': 1130, '_id': 'Thanet'},
#  {'LocalAuthority_count': 882, '_id': 'Greenwich'},
#  {'LocalAuthority_count': 713, '_id': 'Maidstone'},
#  {'LocalAuthority_count': 711, '_id': 'Newham'},
#  {'LocalAuthority_count': 686, '_id': 'Swale'},
#  {'LocalAuthority_count': 680, '_id': 'Chelmsford'},
#  {'LocalAuthority_count': 672, '_id': 'Medway'},
#  {'LocalAuthority_count': 607, '_id': 'Bexley'},
#  {'LocalAuthority_count': 586, '_id': 'Southend-On-Sea'},
#  {'LocalAuthority_count': 542, '_id': 'Tendring'}]

# %%
# Convert mongo result to Pandas DataFrame
result_df = pd.DataFrame(results)

# Display the number of rows in the DataFrame
print("Rows in DataFrame: ", len(result_df))

# Display the first 10 rows of the DataFrame
result_df.head(10)
# Out:
# Rows in DataFrame:  55
#                _id  LocalAuthority_count
# 0           Thanet                  1130
# 1        Greenwich                   882
# 2        Maidstone                   713
# 3           Newham                   711
# 4            Swale                   686
# 5       Chelmsford                   680
# 6           Medway                   672
# 7           Bexley                   607
# 8  Southend-On-Sea                   586
# 9         Tendring                   542
